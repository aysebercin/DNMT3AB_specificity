# %% [markdown]
# # Probability distributions of interactions during MD simulations

# %% [markdown]
# ## Base-specific hydrogen bonds

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
import csv
import os

input_files = os.path.join('DNMT3A_inputs')

a=pd.read_csv(input_files+"/3A-CGC-countbasespechbond", sep="\t", header=None )
a.columns = ["count"]
a['Type'] = 'CGC'

b=pd.read_csv(input_files+"/3A-CGG-countbasespechbond", sep="\t", header=None )
b.columns = ["count"]
b['Type'] = 'CGG'

c=pd.read_csv(input_files+"/3A-CGT-countbasespechbond", sep="\t", header=None )
c.columns = ["count"]
c['Type'] = 'CGT'

d=pd.read_csv(input_files+"/3A-CGA-countbasespechbond", sep="\t", header=None )
d.columns = ["count"]
d['Type'] = 'CGA'

dnmt3a_bshb = pd.concat([a, b, c, d], ignore_index=True)
dnmt3a_bshb
# Out:
#        count Type
# 0          4  CGC
# 1          5  CGC
# 2          3  CGC
# 3          4  CGC
# 4          3  CGC
# ...      ...  ...
# 12811      1  CGA
# 12812      1  CGA
# 12813      1  CGA
# 12814      2  CGA
# 12815      1  CGA
#
# [12816 rows x 2 columns]

# %%
import numpy as np
plt.figure(figsize=(7, 6))

palet=['#C71585','#A9A9A9', 'orange', 'lightseagreen']

sns.violinplot(x="Type", y="count", data=dnmt3a_bshb, bw=0.5, cut=0, scale='count', palette=palet)

plt.xticks(fontsize=13, fontweight='bold')
plt.yticks(np.arange(0, 19, 3))

plt.yticks(fontsize=13, fontweight='bold')
plt.ylabel('Number of h-bonds',fontsize=15, fontweight='bold')
plt.ylim(ymax = 20, ymin = -2)

plt.xlabel('',fontsize=13, fontweight='bold')
plt.title("Base-specific h-bond - DNMT3A",fontsize=20, fontweight='bold')

plt.savefig("3a-cpg-bshb-violin_label.pdf", dpi=600, bbox_inches='tight', format="pdf")

# %% [markdown]
# ## Ionic bonds

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
import csv

input_files = os.path.join('DNMT3A_inputs')

i=pd.read_csv(input_files+"/3A-CGC-countionic", sep="\t", header=None )
i.columns = ["count"]
i['Type'] = 'CGC'

j=pd.read_csv(input_files+"/3A-CGG-countionic", sep="\t", header=None )
j.columns = ["count"]
j['Type'] = 'CGG'

k=pd.read_csv(input_files+"/3A-CGT-countionic", sep="\t", header=None )
k.columns = ["count"]
k['Type'] = 'CGT'

l=pd.read_csv(input_files+"/3A-CGA-countionic", sep="\t", header=None )
l.columns = ["count"]
l['Type'] = 'CGA'


dnmt3a_ionic = pd.concat([i, j, k, l], ignore_index=True)
dnmt3a_ionic
# Out:
#        count Type
# 0          5  CGC
# 1          4  CGC
# 2          5  CGC
# 3          5  CGC
# 4          4  CGC
# ...      ...  ...
# 12811      2  CGA
# 12812      2  CGA
# 12813      3  CGA
# 12814      3  CGA
# 12815      3  CGA
#
# [12816 rows x 2 columns]

# %%
plt.figure(figsize=(7, 6))

palet=['#C71585','#A9A9A9', 'orange', 'lightseagreen']

sns.violinplot(x="Type", y="count", data=dnmt3a_ionic,bw=0.5,cut=0, scale='count', palette=palet)

plt.xticks(fontsize=13, fontweight='bold')
plt.yticks(fontsize=13, fontweight='bold')
plt.ylabel('Number of ionic bonds',fontsize=15, fontweight='bold')
plt.ylim(ymax = 10, ymin = -1)


plt.xlabel('',fontsize=13, fontweight='bold')
plt.title("Ionic bonds - DNMT3A",fontsize=20, fontweight='bold')


plt.savefig("3a-cpg-ionic-violin-label.pdf", dpi=600, bbox_inches='tight', format="pdf")

# %% [markdown]
# ## Hydrophobic interactions

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
import csv

input_files = os.path.join('DNMT3A_inputs')

m=pd.read_csv(input_files+"/3A-CGC-counthydrophobic", sep="\t", header=None )
m.columns = ["count"]
m['Type'] = 'CGC'

n=pd.read_csv(input_files+"/3A-CGG-counthydrophobic", sep="\t", header=None )
n.columns = ["count"]
n['Type'] = 'CGG'

o=pd.read_csv(input_files+"/3A-CGT-counthydrophobic", sep="\t", header=None )
o.columns = ["count"]
o['Type'] = 'CGT'

p=pd.read_csv(input_files+"/3A-CGA-counthydrophobic", sep="\t", header=None )
p.columns = ["count"]
p['Type'] = 'CGA'

dnmt3a_hyd = pd.concat([m, n, o, p], ignore_index=True)
dnmt3a_hyd
# Out:
#        count Type
# 0         11  CGC
# 1         11  CGC
# 2         11  CGC
# 3         12  CGC
# 4         11  CGC
# ...      ...  ...
# 12811     12  CGA
# 12812     14  CGA
# 12813     10  CGA
# 12814     12  CGA
# 12815     12  CGA
#
# [12816 rows x 2 columns]

# %%
plt.figure(figsize=(7, 6))

palet=['#C71585','#A9A9A9', 'orange', 'lightseagreen']

sns.violinplot(x="Type", y="count", data=dnmt3a_hyd,bw=0.5,cut=0, scale='count', palette=palet)

plt.xticks(fontsize=13, fontweight='bold')
plt.yticks(fontsize=13, fontweight='bold')
plt.ylabel('')
plt.ylabel('Number of hydrophobic int.',fontsize=15, fontweight='bold')
plt.ylim(ymax = 30, ymin = -1)

plt.xlabel('',fontsize=13, fontweight='bold')
plt.title("Hydrophobic int. - DNMT3A",fontsize=20, fontweight='bold')

plt.savefig("3a-cpg-hyd-violin-label.pdf", dpi=600, bbox_inches='tight', format="pdf")
