# %% [markdown]
# # Base and res spec h-bond

# %% [markdown]
# ## CGC

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
import csv
import os
import warnings
warnings.filterwarnings('ignore')

input_files = os.path.join('DNMT3B_inputs')

cgc=pd.read_csv(input_files+"/3B-CGC.int.hbonds", sep="\t", header=None)
cgc.columns = ["itype", "chain_a", "chain_b", "resname_a", "resname_b", "resid_a", "resid_b","atom_a", "atom_b" ]

cgc['resid_a'] = cgc['resid_a'] + 570

cgc_inter = cgc.loc[((cgc["chain_a"] == "A") & (cgc["chain_b"] == "B")) | 
                    ((cgc["chain_a"] == "A") & (cgc["chain_b"] == "C")) ]

cgc_spec = cgc_inter.drop(cgc_inter.index[cgc_inter['atom_b'].isin(["P","O1P","OP1","OP2","O2P","C5'",
                                                           "O5'","C4'","O4'","C3'","O3'","C2'",
                                                           "C1'","H1'","1H2'","2H2'","H3'","H4'","1H5'","2H5'"])])

cgc_spec_res = cgc_spec.drop(cgc_spec.index[cgc_spec['atom_a'].isin(["N","CA","C","O","H","HA"])])


cgc_spec_res["resname_a"] = cgc_spec_res["resname_a"].astype(str) + cgc_spec_res["resid_a"].astype(str)
#
cgc_spec_res=cgc_spec_res.drop(columns=['resid_a'])
cgc_spec_res['Type'] = '3B:CGC'
#
cgc_spec_res
# Out:
#         itype chain_a chain_b resname_a resname_b  resid_b atom_a atom_b  \
# 74      hbond       A       B    ARG661        DA      291    NH2     N9
# 75      hbond       A       B    ARG661        DC      290    NH2     O2
# 132     hbond       A       C    ARG731        DC      298     NE     O2
# 138     hbond       A       C    ARG733        DC      298    NH2     O2
# 170     hbond       A       B    LYS777        DG      285     NZ     O6
# ...       ...     ...     ...       ...       ...      ...    ...    ...
# 841949  hbond       A       C    ARG733        DC      298     NE     N3
# 841951  hbond       A       C    ARG733        DC      298    NH2     O2
# 841982  hbond       A       B    LYS777        DG      285     NZ     O6
# 842059  hbond       A       C    GLU697        DC      298    OE1     N4
# 842060  hbond       A       C    GLU697        DC      298    OE2     N4
#
#           Type
# 74      3B:CGC
# 75      3B:CGC
# 132     3B:CGC
# 138     3B:CGC
# 170     3B:CGC
# ...        ...
# 841949  3B:CGC
# 841951  3B:CGC
# 841982  3B:CGC
# 842059  3B:CGC
# 842060  3B:CGC
#
# [26256 rows x 9 columns]

# %%
#Function for convert residue number of nucleotides to nucleotide position
def nucleotide_pos(df):
    df['resid_b'] = df['resid_b'].astype(str).str.replace('284',"(+5')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('285',"(+4')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('286',"(+3')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('287',"(+2')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('288',"(+1')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('289',"(0')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('290',"(-1')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('291',"(-2')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('292',"(-3')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('293',"(-4')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('294',"(-4)")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('295',"(-3)")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('296',"(-2)")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('297',"(-1)")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('298',"(0)")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('299',"(+1)")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('300',"(+2)")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('301',"(+3)")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('302',"(+4)")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('303',"(+5)")

# %%
nucleotide_pos(cgc_spec_res)
cgc_spec_res
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 74      hbond       A       B    ARG661        DA   (-2')    NH2     N9
# 75      hbond       A       B    ARG661        DC   (-1')    NH2     O2
# 132     hbond       A       C    ARG731        DC     (0)     NE     O2
# 138     hbond       A       C    ARG733        DC     (0)    NH2     O2
# 170     hbond       A       B    LYS777        DG   (+4')     NZ     O6
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 841949  hbond       A       C    ARG733        DC     (0)     NE     N3
# 841951  hbond       A       C    ARG733        DC     (0)    NH2     O2
# 841982  hbond       A       B    LYS777        DG   (+4')     NZ     O6
# 842059  hbond       A       C    GLU697        DC     (0)    OE1     N4
# 842060  hbond       A       C    GLU697        DC     (0)    OE2     N4
#
#           Type
# 74      3B:CGC
# 75      3B:CGC
# 132     3B:CGC
# 138     3B:CGC
# 170     3B:CGC
# ...        ...
# 841949  3B:CGC
# 841951  3B:CGC
# 841982  3B:CGC
# 842059  3B:CGC
# 842060  3B:CGC
#
# [26256 rows x 9 columns]

# %%
cgc_spec_res['resname_a'] = cgc_spec_res['resname_a'].str.title()

#discarding flipped cytosine
cgc_spec_res=cgc_spec_res.drop(cgc_spec_res.loc[cgc_spec_res['resid_b']=="(0)"].index)
#
cgc_spec_res['pairwise'] = cgc_spec_res['resname_a'].str.cat(cgc_spec_res['resid_b'],sep="-")
cgc_spec_res['pair_freq'] = cgc_spec_res.groupby('pairwise')['pairwise'].transform('count')
#
cgc_spec_res['atom_atom'] = cgc_spec_res['resname_a']+"-"+ cgc_spec_res['atom_a']+"-"+ cgc_spec_res['resid_b'] +"-"+ cgc_spec_res['atom_b']
cgc_spec_res['atom_atom_freq'] = cgc_spec_res.groupby('atom_atom')['atom_atom'].transform('count')
#
cgc_spec_res
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 74      hbond       A       B    Arg661        DA   (-2')    NH2     N9
# 75      hbond       A       B    Arg661        DC   (-1')    NH2     O2
# 170     hbond       A       B    Lys777        DG   (+4')     NZ     O6
# 186     hbond       A       C    Lys785        DG    (-1)     NZ     O6
# 341     hbond       A       B    Arg661        DC   (-1')    NH2     O2
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 841719  hbond       A       B    Lys777        DG   (+4')     NZ     O6
# 841720  hbond       A       C    Lys777        DT    (+3)     NZ     O4
# 841885  hbond       A       B    Asn656        DA   (-2')    ND2     N3
# 841893  hbond       A       B    Arg661        DC   (-1')    NH2     O2
# 841982  hbond       A       B    Lys777        DG   (+4')     NZ     O6
#
#           Type      pairwise  pair_freq            atom_atom  atom_atom_freq
# 74      3B:CGC  Arg661-(-2')        538  Arg661-NH2-(-2')-N9             282
# 75      3B:CGC  Arg661-(-1')       3591  Arg661-NH2-(-1')-O2            3194
# 170     3B:CGC  Lys777-(+4')       2072   Lys777-NZ-(+4')-O6            1708
# 186     3B:CGC   Lys785-(-1)        550    Lys785-NZ-(-1)-O6             342
# 341     3B:CGC  Arg661-(-1')       3591  Arg661-NH2-(-1')-O2            3194
# ...        ...           ...        ...                  ...             ...
# 841719  3B:CGC  Lys777-(+4')       2072   Lys777-NZ-(+4')-O6            1708
# 841720  3B:CGC   Lys777-(+3)        790    Lys777-NZ-(+3)-O4             790
# 841885  3B:CGC  Asn656-(-2')       2776  Asn656-ND2-(-2')-N3            2776
# 841893  3B:CGC  Arg661-(-1')       3591  Arg661-NH2-(-1')-O2            3194
# 841982  3B:CGC  Lys777-(+4')       2072   Lys777-NZ-(+4')-O6            1708
#
# [14098 rows x 13 columns]

# %%
cgc_compl = cgc_spec_res[cgc_spec_res['resid_b'].isin(("(+3')","(+2')","(+1')"))]
cgc_compl['Strand'] = 'CGC-compl'

cgc_target = cgc_spec_res[cgc_spec_res['resid_b'].isin(("(+3)","(+2)","(+1)"))]
cgc_target['Strand'] = 'CGC-target'

cgc_all=cgc_compl.append(cgc_target)
cgc_all=cgc_all.sort_values(('atom_atom_freq') , ascending=False)
cgc_all
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 841720  hbond       A       C    Lys777        DT    (+3)     NZ     O4
# 218201  hbond       A       C    Lys777        DT    (+3)     NZ     O4
# 216642  hbond       A       C    Lys777        DT    (+3)     NZ     O4
# 215845  hbond       A       C    Lys777        DT    (+3)     NZ     O4
# 211921  hbond       A       C    Lys777        DT    (+3)     NZ     O4
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 490231  hbond       A       B    Lys785        DC   (+1')     NZ     N4
# 607178  hbond       A       B    Ser778        DA   (+3')     OG     N6
# 757641  hbond       A       C    Asn779        DC    (+2)    OD1     N4
# 711201  hbond       A       B    Gln787        DA   (+3')    NE2     N7
# 623523  hbond       A       B    Lys777        DA   (+3')     NZ     N7
#
#           Type      pairwise  pair_freq            atom_atom  atom_atom_freq  \
# 841720  3B:CGC   Lys777-(+3)        790    Lys777-NZ-(+3)-O4             790
# 218201  3B:CGC   Lys777-(+3)        790    Lys777-NZ-(+3)-O4             790
# 216642  3B:CGC   Lys777-(+3)        790    Lys777-NZ-(+3)-O4             790
# 215845  3B:CGC   Lys777-(+3)        790    Lys777-NZ-(+3)-O4             790
# 211921  3B:CGC   Lys777-(+3)        790    Lys777-NZ-(+3)-O4             790
# ...        ...           ...        ...                  ...             ...
# 490231  3B:CGC  Lys785-(+1')          2   Lys785-NZ-(+1')-N4               2
# 607178  3B:CGC  Ser778-(+3')          7   Ser778-OG-(+3')-N6               2
# 757641  3B:CGC   Asn779-(+2)          5   Asn779-OD1-(+2)-N4               1
# 711201  3B:CGC  Gln787-(+3')          1  Gln787-NE2-(+3')-N7               1
# 623523  3B:CGC  Lys777-(+3')         11   Lys777-NZ-(+3')-N7               1
#
#             Strand
# 841720  CGC-target
# 218201  CGC-target
# 216642  CGC-target
# 215845  CGC-target
# 211921  CGC-target
# ...            ...
# 490231   CGC-compl
# 607178   CGC-compl
# 757641  CGC-target
# 711201   CGC-compl
# 623523   CGC-compl
#
# [3550 rows x 14 columns]

# %%
cgc_sig = cgc_all[cgc_all['atom_atom_freq'] > (3204*0.10)]

# %%
sns.set(style="ticks")

palet=['#888888', '#DCDCDC']

plt.figure(figsize=(5,10))
ax = sns.barplot(x="atom_atom", y="atom_atom_freq", hue="Strand", palette=palet, 
                 dodge=False,
                 data=cgc_sig,  lw=1, edgecolor='0.2')
plt.xticks(rotation=30)
plt.legend(loc='upper center')
plt.xticks(fontsize=22)
plt.yticks(fontsize=25)
plt.ylim(ymax = 2300, ymin = 0)
plt.xlabel('', fontsize=15, fontweight='bold')
plt.ylabel('',fontsize=15, fontweight='bold')
plt.title("",fontsize=20, fontweight='bold')

plt.savefig("Comp-3b-cgc-atom-atom-c-flank-f.pdf", dpi=600, bbox_inches='tight', format="pdf")

# %% [markdown]
# ## CGG

# %%
cgg=pd.read_csv(input_files+"/3B-CGG.int.hbonds", sep="\t", header=None)
cgg.columns = ["itype", "chain_a", "chain_b", "resname_a", "resname_b", "resid_a", "resid_b","atom_a", "atom_b" ]

cgg['resid_a'] = cgg['resid_a'] + 570

cgg_inter = cgg.loc[((cgg["chain_a"] == "A") & (cgg["chain_b"] == "B")) | 
                    ((cgg["chain_a"] == "A") & (cgg["chain_b"] == "C")) ]

cgg_spec = cgg_inter.drop(cgg_inter.index[cgg_inter['atom_b'].isin(["P","O1P","OP1","OP2","O2P","C5'",
                                                           "O5'","C4'","O4'","C3'","O3'","C2'",
                                                           "C1'","H1'","1H2'","2H2'","H3'","H4'","1H5'","2H5'"])])

cgg_spec_res = cgg_spec.drop(cgg_spec.index[cgg_spec['atom_a'].isin(["N","CA","C","O","H","HA"])])


cgg_spec_res["resname_a"] = cgg_spec_res["resname_a"].astype(str) + cgg_spec_res["resid_a"].astype(str)
#
cgg_spec_res=cgg_spec_res.drop(columns=['resid_a'])
cgg_spec_res['Type'] = '3B:CGG'
#
nucleotide_pos(cgg_spec_res)
cgg_spec_res
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 67      hbond       A       B    ASN656        DA   (-2')    ND2     N3
# 73      hbond       A       B    ARG661        DC   (-1')    NH2     O2
# 127     hbond       A       C    ARG731        DC     (0)     NE     O2
# 130     hbond       A       C    ARG731        DC     (0)    NH2     O2
# 133     hbond       A       C    ARG733        DC     (0)     NE     N3
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 839218  hbond       A       C    LYS777        DG    (+2)     NZ     N7
# 839228  hbond       A       C    LYS785        DT    (-2)     NZ     O4
# 839291  hbond       A       B    ASN779        DC   (+2')    ND2     N4
# 839306  hbond       A       C    GLU697        DC     (0)    OE1     N4
# 839307  hbond       A       C    GLU697        DC     (0)    OE2     N4
#
#           Type
# 67      3B:CGG
# 73      3B:CGG
# 127     3B:CGG
# 130     3B:CGG
# 133     3B:CGG
# ...        ...
# 839218  3B:CGG
# 839228  3B:CGG
# 839291  3B:CGG
# 839306  3B:CGG
# 839307  3B:CGG
#
# [25427 rows x 9 columns]

# %%
cgg_spec_res['resname_a'] = cgg_spec_res['resname_a'].str.title()

#discarding flipped cytosine
cgg_spec_res=cgg_spec_res.drop(cgg_spec_res.loc[cgg_spec_res['resid_b']=="(0)"].index)
#
cgg_spec_res['pairwise'] = cgg_spec_res['resname_a'].str.cat(cgg_spec_res['resid_b'],sep="-")
cgg_spec_res['pair_freq'] = cgg_spec_res.groupby('pairwise')['pairwise'].transform('count')
#
cgg_spec_res['atom_atom'] = cgg_spec_res['resname_a']+"-"+ cgg_spec_res['atom_a']+"-"+ cgg_spec_res['resid_b'] +"-"+ cgg_spec_res['atom_b']
cgg_spec_res['atom_atom_freq'] = cgg_spec_res.groupby('atom_atom')['atom_atom'].transform('count')
#
cgg_spec_res
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 67      hbond       A       B    Asn656        DA   (-2')    ND2     N3
# 73      hbond       A       B    Arg661        DC   (-1')    NH2     O2
# 159     hbond       A       C    Gln772        DG    (-1)    NE2     N7
# 164     hbond       A       C    Lys777        DG    (+1)     NZ     N7
# 172     hbond       A       B    Lys785        DG    (0')     NZ     N7
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 839127  hbond       A       B    Arg661        DA   (-2')    NH2     N3
# 839217  hbond       A       C    Lys777        DT    (+3)     NZ     O4
# 839218  hbond       A       C    Lys777        DG    (+2)     NZ     N7
# 839228  hbond       A       C    Lys785        DT    (-2)     NZ     O4
# 839291  hbond       A       B    Asn779        DC   (+2')    ND2     N4
#
#           Type      pairwise  pair_freq            atom_atom  atom_atom_freq
# 67      3B:CGG  Asn656-(-2')       1841  Asn656-ND2-(-2')-N3            1841
# 73      3B:CGG  Arg661-(-1')       2842  Arg661-NH2-(-1')-O2            2652
# 159     3B:CGG   Gln772-(-1)          4   Gln772-NE2-(-1)-N7               4
# 164     3B:CGG   Lys777-(+1)       1511    Lys777-NZ-(+1)-N7            1203
# 172     3B:CGG   Lys785-(0')        668    Lys785-NZ-(0')-N7             334
# ...        ...           ...        ...                  ...             ...
# 839127  3B:CGG  Arg661-(-2')       1157  Arg661-NH2-(-2')-N3             679
# 839217  3B:CGG   Lys777-(+3)        627    Lys777-NZ-(+3)-O4             627
# 839218  3B:CGG   Lys777-(+2)        812    Lys777-NZ-(+2)-N7             690
# 839228  3B:CGG   Lys785-(-2)        226    Lys785-NZ-(-2)-O4             226
# 839291  3B:CGG  Asn779-(+2')       1215  Asn779-ND2-(+2')-N4             249
#
# [13665 rows x 13 columns]

# %%
cgg_compl = cgg_spec_res[cgg_spec_res['resid_b'].isin(("(+3')","(+2')","(+1')"))]
cgg_compl['Strand'] = 'cgg-compl'

cgg_target = cgg_spec_res[cgg_spec_res['resid_b'].isin(("(+3)","(+2)","(+1)"))]
cgg_target['Strand'] = 'cgg-target'

cgg_all=cgg_compl.append(cgg_target)
cgg_all=cgg_all.sort_values(('atom_atom_freq') , ascending=False)
cgg_all
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 200856  hbond       A       C    Lys777        DG    (+1)     NZ     N7
# 149398  hbond       A       C    Lys777        DG    (+1)     NZ     N7
# 149916  hbond       A       C    Lys777        DG    (+1)     NZ     N7
# 150179  hbond       A       C    Lys777        DG    (+1)     NZ     N7
# 150450  hbond       A       C    Lys777        DG    (+1)     NZ     N7
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 183762  hbond       A       B    Lys777        DC   (+1')     NZ     N4
# 570364  hbond       A       B    Asn779        DA   (+3')    ND2     N6
# 114398  hbond       A       B    Lys777        DC   (+1')     NZ     N4
# 570101  hbond       A       B    Asn779        DA   (+3')    ND2     N6
# 78947   hbond       A       B    Lys785        DC   (+1')     NZ     N4
#
#           Type      pairwise  pair_freq            atom_atom  atom_atom_freq  \
# 200856  3B:CGG   Lys777-(+1)       1511    Lys777-NZ-(+1)-N7            1203
# 149398  3B:CGG   Lys777-(+1)       1511    Lys777-NZ-(+1)-N7            1203
# 149916  3B:CGG   Lys777-(+1)       1511    Lys777-NZ-(+1)-N7            1203
# 150179  3B:CGG   Lys777-(+1)       1511    Lys777-NZ-(+1)-N7            1203
# 150450  3B:CGG   Lys777-(+1)       1511    Lys777-NZ-(+1)-N7            1203
# ...        ...           ...        ...                  ...             ...
# 183762  3B:CGG  Lys777-(+1')          3   Lys777-NZ-(+1')-N4               3
# 570364  3B:CGG  Asn779-(+3')        407  Asn779-ND2-(+3')-N6               3
# 114398  3B:CGG  Lys777-(+1')          3   Lys777-NZ-(+1')-N4               3
# 570101  3B:CGG  Asn779-(+3')        407  Asn779-ND2-(+3')-N6               3
# 78947   3B:CGG  Lys785-(+1')          1   Lys785-NZ-(+1')-N4               1
#
#             Strand
# 200856  cgg-target
# 149398  cgg-target
# 149916  cgg-target
# 150179  cgg-target
# 150450  cgg-target
# ...            ...
# 183762   cgg-compl
# 570364   cgg-compl
# 114398   cgg-compl
# 570101   cgg-compl
# 78947    cgg-compl
#
# [5207 rows x 14 columns]

# %%
cgg_sig = cgg_all[cgg_all['atom_atom_freq'] > (3204*0.10)]

# %%
palet=['#746AB0', '#C1B8F9']

plt.figure(figsize=(5,10))
ax = sns.barplot(x="atom_atom", y="atom_atom_freq", hue="Strand", palette=palet, 
                 dodge=False,
                 data=cgg_sig, lw=1, edgecolor='0.2')
plt.xticks(rotation=30)
plt.legend(loc='upper center')
plt.xticks(fontsize=22)
plt.yticks(fontsize=25)
plt.ylim(ymax = 2300, ymin = 0)
plt.xlabel('', fontsize=15, fontweight='bold')
plt.ylabel('Number of h-bonds',fontsize=33, fontweight='bold')
plt.title("",fontsize=20, fontweight='bold')

plt.savefig("Comp-3b-cgg-atom-atom-c-flank-f.pdf", dpi=600, bbox_inches='tight', format="pdf")

# %% [markdown]
# ## CGT

# %%
cgt=pd.read_csv(input_files+"/3B-CGT.int.hbonds", sep="\t", header=None)
cgt.columns = ["itype", "chain_a", "chain_b", "resname_a", "resname_b", "resid_a", "resid_b","atom_a", "atom_b" ]

cgt['resid_a'] = cgt['resid_a'] + 570

cgt_inter = cgt.loc[((cgt["chain_a"] == "A") & (cgt["chain_b"] == "B")) | 
                    ((cgt["chain_a"] == "A") & (cgt["chain_b"] == "C")) ]

cgt_spec = cgt_inter.drop(cgt_inter.index[cgt_inter['atom_b'].isin(["P","O1P","OP1","OP2","O2P","C5'",
                                                           "O5'","C4'","O4'","C3'","O3'","C2'",
                                                           "C1'","H1'","1H2'","2H2'","H3'","H4'","1H5'","2H5'"])])

cgt_spec_res = cgt_spec.drop(cgt_spec.index[cgt_spec['atom_a'].isin(["N","CA","C","O","H","HA"])])


cgt_spec_res["resname_a"] = cgt_spec_res["resname_a"].astype(str) + cgt_spec_res["resid_a"].astype(str)
#
cgt_spec_res=cgt_spec_res.drop(columns=['resid_a'])
cgt_spec_res['Type'] = '3B:CGT'
#
nucleotide_pos(cgt_spec_res)
cgt_spec_res
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 76      hbond       A       B    ASN656        DA   (-2')    ND2     N3
# 84      hbond       A       B    ARG661        DC   (-1')    NH2     O2
# 177     hbond       A       C    LYS777        DG    (+1)     NZ     O6
# 186     hbond       A       C    LYS785        DA    (-3)     NZ     N7
# 260     hbond       A       C    GLU697        DC     (0)    OE1     N4
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 842885  hbond       A       C    ARG733        DC     (0)    NH2     O2
# 842917  hbond       A       B    LYS777        DG   (+4')     NZ     O6
# 842918  hbond       A       C    LYS777        DT    (+3)     NZ     O4
# 842985  hbond       A       B    ASN779        DC   (+1')    OD1     N4
# 843000  hbond       A       C    GLU697        DC     (0)    OE1     N4
#
#           Type
# 76      3B:CGT
# 84      3B:CGT
# 177     3B:CGT
# 186     3B:CGT
# 260     3B:CGT
# ...        ...
# 842885  3B:CGT
# 842917  3B:CGT
# 842918  3B:CGT
# 842985  3B:CGT
# 843000  3B:CGT
#
# [26240 rows x 9 columns]

# %%
cgt_spec_res['resname_a'] = cgt_spec_res['resname_a'].str.title()

#discarding flipped cytosine
cgt_spec_res=cgt_spec_res.drop(cgt_spec_res.loc[cgt_spec_res['resid_b']=="(0)"].index)
#
cgt_spec_res['pairwise'] = cgt_spec_res['resname_a'].str.cat(cgt_spec_res['resid_b'],sep="-")
cgt_spec_res['pair_freq'] = cgt_spec_res.groupby('pairwise')['pairwise'].transform('count')
#
cgt_spec_res['atom_atom'] = cgt_spec_res['resname_a']+"-"+ cgt_spec_res['atom_a']+"-"+ cgt_spec_res['resid_b'] +"-"+ cgt_spec_res['atom_b']
cgt_spec_res['atom_atom_freq'] = cgt_spec_res.groupby('atom_atom')['atom_atom'].transform('count')
#
cgt_spec_res
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 76      hbond       A       B    Asn656        DA   (-2')    ND2     N3
# 84      hbond       A       B    Arg661        DC   (-1')    NH2     O2
# 177     hbond       A       C    Lys777        DG    (+1)     NZ     O6
# 186     hbond       A       C    Lys785        DA    (-3)     NZ     N7
# 343     hbond       A       B    Asn656        DA   (-2')    ND2     N3
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 842827  hbond       A       B    Arg661        DC   (-1')    NH2     O2
# 842828  hbond       A       B    Arg661        DA   (-2')    NH2     N3
# 842917  hbond       A       B    Lys777        DG   (+4')     NZ     O6
# 842918  hbond       A       C    Lys777        DT    (+3)     NZ     O4
# 842985  hbond       A       B    Asn779        DC   (+1')    OD1     N4
#
#           Type      pairwise  pair_freq            atom_atom  atom_atom_freq
# 76      3B:CGT  Asn656-(-2')       2325  Asn656-ND2-(-2')-N3            2325
# 84      3B:CGT  Arg661-(-1')       3904  Arg661-NH2-(-1')-O2            2998
# 177     3B:CGT   Lys777-(+1)       1155    Lys777-NZ-(+1)-O6            1086
# 186     3B:CGT   Lys785-(-3)         35    Lys785-NZ-(-3)-N7              34
# 343     3B:CGT  Asn656-(-2')       2325  Asn656-ND2-(-2')-N3            2325
# ...        ...           ...        ...                  ...             ...
# 842827  3B:CGT  Arg661-(-1')       3904  Arg661-NH2-(-1')-O2            2998
# 842828  3B:CGT  Arg661-(-2')        778  Arg661-NH2-(-2')-N3             479
# 842917  3B:CGT  Lys777-(+4')       1415   Lys777-NZ-(+4')-O6            1206
# 842918  3B:CGT   Lys777-(+3)        667    Lys777-NZ-(+3)-O4             667
# 842985  3B:CGT  Asn779-(+1')        157  Asn779-OD1-(+1')-N4              56
#
# [16193 rows x 13 columns]

# %%
cgt_compl = cgt_spec_res[cgt_spec_res['resid_b'].isin(("(+3')","(+2')","(+1')"))]
cgt_compl['Strand'] = 'cgt-compl'

cgt_target = cgt_spec_res[cgt_spec_res['resid_b'].isin(("(+3)","(+2)","(+1)"))]
cgt_target['Strand'] = 'cgt-target'

cgt_all=cgt_compl.append(cgt_target)
cgt_all=cgt_all.sort_values(('atom_atom_freq') , ascending=False)
cgt_all
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 421062  hbond       A       B    Asn779        DA   (+2')    OD1     N6
# 363251  hbond       A       B    Asn779        DA   (+2')    OD1     N6
# 362984  hbond       A       B    Asn779        DA   (+2')    OD1     N6
# 586768  hbond       A       B    Asn779        DA   (+2')    OD1     N6
# 587025  hbond       A       B    Asn779        DA   (+2')    OD1     N6
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 791116  hbond       A       B    Asn779        DA   (+3')    ND2     N6
# 256766  hbond       A       B    Lys777        DA   (+2')     NZ     N6
# 278468  hbond       A       B    Lys777        DA   (+2')     NZ     N6
# 253150  hbond       A       B    Lys777        DA   (+2')     NZ     N6
# 33608   hbond       A       C    Thr775        DG    (+1)    OG1     N7
#
#           Type      pairwise  pair_freq            atom_atom  atom_atom_freq  \
# 421062  3B:CGT  Asn779-(+2')       2129  Asn779-OD1-(+2')-N6            1140
# 363251  3B:CGT  Asn779-(+2')       2129  Asn779-OD1-(+2')-N6            1140
# 362984  3B:CGT  Asn779-(+2')       2129  Asn779-OD1-(+2')-N6            1140
# 586768  3B:CGT  Asn779-(+2')       2129  Asn779-OD1-(+2')-N6            1140
# 587025  3B:CGT  Asn779-(+2')       2129  Asn779-OD1-(+2')-N6            1140
# ...        ...           ...        ...                  ...             ...
# 791116  3B:CGT  Asn779-(+3')        710  Asn779-ND2-(+3')-N6               5
# 256766  3B:CGT  Lys777-(+2')          3   Lys777-NZ-(+2')-N6               3
# 278468  3B:CGT  Lys777-(+2')          3   Lys777-NZ-(+2')-N6               3
# 253150  3B:CGT  Lys777-(+2')          3   Lys777-NZ-(+2')-N6               3
# 33608   3B:CGT   Thr775-(+1)          1   Thr775-OG1-(+1)-N7               1
#
#             Strand
# 421062   cgt-compl
# 363251   cgt-compl
# 362984   cgt-compl
# 586768   cgt-compl
# 587025   cgt-compl
# ...            ...
# 791116   cgt-compl
# 256766   cgt-compl
# 278468   cgt-compl
# 253150   cgt-compl
# 33608   cgt-target
#
# [6089 rows x 14 columns]

# %%
cgt_sig = cgt_all[cgt_all['atom_atom_freq'] > (3204*0.10)]

# %%
#palet=['#C71585','#DCDCDC', 'orange', 'lightseagreen']
palet=['#FFD491','orange']

plt.figure(figsize=(7,10))
ax = sns.barplot(x="atom_atom", y="atom_atom_freq", hue="Strand", palette=palet, 
                 dodge=False,
                 data=cgt_sig,  lw=1, edgecolor='0.2')
plt.xticks(rotation=30)
plt.legend(loc='upper center')
plt.xticks(fontsize=22)
plt.yticks(fontsize=25)
plt.ylim(ymax = 2300, ymin = 0)
plt.xlabel('', fontsize=15, fontweight='bold')
plt.ylabel('',fontsize=15, fontweight='bold')
plt.title("",fontsize=20, fontweight='bold')

plt.savefig("Comp-3b-cgt-atom-atom-c-flank-f.pdf", dpi=600, bbox_inches='tight', format="pdf")

# %% [markdown]
# ## CGA

# %%
cga=pd.read_csv(input_files+"/3B-CGA.int.hbonds", sep="\t", header=None)
cga.columns = ["itype", "chain_a", "chain_b", "resname_a", "resname_b", "resid_a", "resid_b","atom_a", "atom_b" ]

cga['resid_a'] = cga['resid_a'] + 570

cga_inter = cga.loc[((cga["chain_a"] == "A") & (cga["chain_b"] == "B")) | 
                    ((cga["chain_a"] == "A") & (cga["chain_b"] == "C")) ]

cga_spec = cga_inter.drop(cga_inter.index[cga_inter['atom_b'].isin(["P","O1P","OP1","OP2","O2P","C5'",
                                                           "O5'","C4'","O4'","C3'","O3'","C2'",
                                                           "C1'","H1'","1H2'","2H2'","H3'","H4'","1H5'","2H5'"])])

cga_spec_res = cga_spec.drop(cga_spec.index[cga_spec['atom_a'].isin(["N","CA","C","O","H","HA"])])


cga_spec_res["resname_a"] = cga_spec_res["resname_a"].astype(str) + cga_spec_res["resid_a"].astype(str)
#
cga_spec_res=cga_spec_res.drop(columns=['resid_a'])
cga_spec_res['Type'] = '3B:CGA'
#
nucleotide_pos(cga_spec_res)
cga_spec_res
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 71      hbond       A       B    ASN656        DA   (-2')    ND2     N3
# 78      hbond       A       B    ARG661        DC   (-1')    NH2     O2
# 136     hbond       A       C    ARG731        DC     (0)     NE     O2
# 141     hbond       A       C    ARG733        DC     (0)     NE     N3
# 143     hbond       A       C    ARG733        DC     (0)    NH2     O2
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 845287  hbond       A       C    ARG733        DC     (0)     NE     O2
# 845290  hbond       A       C    ARG733        DC     (0)    NH2     O2
# 845321  hbond       A       C    LYS777        DT    (+3)     NZ     O4
# 845323  hbond       A       C    ASN779        DG    (+1)    ND2     O6
# 845405  hbond       A       C    GLU697        DC     (0)    OE2     N4
#
#           Type
# 71      3B:CGA
# 78      3B:CGA
# 136     3B:CGA
# 141     3B:CGA
# 143     3B:CGA
# ...        ...
# 845287  3B:CGA
# 845290  3B:CGA
# 845321  3B:CGA
# 845323  3B:CGA
# 845405  3B:CGA
#
# [25807 rows x 9 columns]

# %%
cga_spec_res['resname_a'] = cga_spec_res['resname_a'].str.title()

#discarding flipped cytosine
cga_spec_res=cga_spec_res.drop(cga_spec_res.loc[cga_spec_res['resid_b']=="(0)"].index)
#
cga_spec_res['pairwise'] = cga_spec_res['resname_a'].str.cat(cga_spec_res['resid_b'],sep="-")
cga_spec_res['pair_freq'] = cga_spec_res.groupby('pairwise')['pairwise'].transform('count')
#
cga_spec_res['atom_atom'] = cga_spec_res['resname_a']+"-"+ cga_spec_res['atom_a']+"-"+ cga_spec_res['resid_b'] +"-"+ cga_spec_res['atom_b']
cga_spec_res['atom_atom_freq'] = cga_spec_res.groupby('atom_atom')['atom_atom'].transform('count')
#
cga_spec_res
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 71      hbond       A       B    Asn656        DA   (-2')    ND2     N3
# 78      hbond       A       B    Arg661        DC   (-1')    NH2     O2
# 174     hbond       A       C    Lys777        DT    (+3)     NZ     O4
# 175     hbond       A       B    Lys777        DG   (+4')     NZ     O6
# 334     hbond       A       B    Asn656        DA   (-2')    ND2     N3
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 845061  hbond       A       B    Lys785        DG    (0')     NZ     O6
# 845135  hbond       A       C    Arg661        DG    (-1)    NH2     N2
# 845231  hbond       A       B    Arg661        DC   (-1')    NH2     O2
# 845321  hbond       A       C    Lys777        DT    (+3)     NZ     O4
# 845323  hbond       A       C    Asn779        DG    (+1)    ND2     O6
#
#           Type      pairwise  pair_freq            atom_atom  atom_atom_freq
# 71      3B:CGA  Asn656-(-2')       2223  Asn656-ND2-(-2')-N3            2223
# 78      3B:CGA  Arg661-(-1')       3253  Arg661-NH2-(-1')-O2            2879
# 174     3B:CGA   Lys777-(+3)       1095    Lys777-NZ-(+3)-O4            1095
# 175     3B:CGA  Lys777-(+4')        765   Lys777-NZ-(+4')-O6             680
# 334     3B:CGA  Asn656-(-2')       2223  Asn656-ND2-(-2')-N3            2223
# ...        ...           ...        ...                  ...             ...
# 845061  3B:CGA   Lys785-(0')        360    Lys785-NZ-(0')-O6             269
# 845135  3B:CGA   Arg661-(-1)         16   Arg661-NH2-(-1)-N2              15
# 845231  3B:CGA  Arg661-(-1')       3253  Arg661-NH2-(-1')-O2            2879
# 845321  3B:CGA   Lys777-(+3)       1095    Lys777-NZ-(+3)-O4            1095
# 845323  3B:CGA   Asn779-(+1)       2096   Asn779-ND2-(+1)-O6            2094
#
# [13834 rows x 13 columns]

# %%
cga_compl = cga_spec_res[cga_spec_res['resid_b'].isin(("(+3')","(+2')","(+1')"))]
cga_compl['Strand'] = 'cga-compl'

cga_target = cga_spec_res[cga_spec_res['resid_b'].isin(("(+3)","(+2)","(+1)"))]
cga_target['Strand'] = 'cga-target'

cga_all=cga_compl.append(cga_target)
cga_all=cga_all.sort_values(('atom_atom_freq') , ascending=False)
cga_all
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 362732  hbond       A       C    Asn779        DG    (+1)    ND2     O6
# 447454  hbond       A       C    Asn779        DG    (+1)    ND2     O6
# 447980  hbond       A       C    Asn779        DG    (+1)    ND2     O6
# 448243  hbond       A       C    Asn779        DG    (+1)    ND2     O6
# 448494  hbond       A       C    Asn779        DG    (+1)    ND2     O6
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 556989  hbond       A       C    Asn779        DG    (+1)    ND2     N7
# 548708  hbond       A       C    Asn779        DG    (+1)    ND2     N7
# 833390  hbond       A       B    Asn779        DC   (+1')    OD1     N4
# 538991  hbond       A       B    Asn779        DA   (+3')    ND2     N7
# 346006  hbond       A       B    Ser778        DA   (+3')     OG     N6
#
#           Type      pairwise  pair_freq            atom_atom  atom_atom_freq  \
# 362732  3B:CGA   Asn779-(+1)       2096   Asn779-ND2-(+1)-O6            2094
# 447454  3B:CGA   Asn779-(+1)       2096   Asn779-ND2-(+1)-O6            2094
# 447980  3B:CGA   Asn779-(+1)       2096   Asn779-ND2-(+1)-O6            2094
# 448243  3B:CGA   Asn779-(+1)       2096   Asn779-ND2-(+1)-O6            2094
# 448494  3B:CGA   Asn779-(+1)       2096   Asn779-ND2-(+1)-O6            2094
# ...        ...           ...        ...                  ...             ...
# 556989  3B:CGA   Asn779-(+1)       2096   Asn779-ND2-(+1)-N7               2
# 548708  3B:CGA   Asn779-(+1)       2096   Asn779-ND2-(+1)-N7               2
# 833390  3B:CGA  Asn779-(+1')         35  Asn779-OD1-(+1')-N4               1
# 538991  3B:CGA  Asn779-(+3')         12  Asn779-ND2-(+3')-N7               1
# 346006  3B:CGA  Ser778-(+3')         14   Ser778-OG-(+3')-N6               1
#
#             Strand
# 362732  cga-target
# 447454  cga-target
# 447980  cga-target
# 448243  cga-target
# 448494  cga-target
# ...            ...
# 556989  cga-target
# 548708  cga-target
# 833390   cga-compl
# 538991   cga-compl
# 346006   cga-compl
#
# [4499 rows x 14 columns]

# %%
cga_sig = cga_all[cga_all['atom_atom_freq'] > (3204*0.10)]

# %%
#palet=['#C71585','#DCDCDC', 'orange', 'lightseagreen']
palet=['lightseagreen','#87D3D3']

plt.figure(figsize=(3,10))
ax = sns.barplot(x="atom_atom", y="atom_atom_freq", hue="Strand", palette=palet, 
                 dodge=False,
                 data=cga_sig,  lw=1, edgecolor='0.2')
plt.xticks(rotation=30)
plt.legend(loc='upper center')
plt.xticks(fontsize=22)
plt.yticks(fontsize=25)
plt.ylim(ymax = 2300, ymin = 0)
plt.xlabel('', fontsize=15, fontweight='bold')
plt.ylabel('',fontsize=15, fontweight='bold')
plt.title("",fontsize=20, fontweight='bold')

plt.savefig("Comp-3b-cga-atom-atom-c-flank-f.pdf", dpi=600, bbox_inches='tight', format="pdf")
