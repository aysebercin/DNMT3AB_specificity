# %% [markdown]
# # Base and res spec h-bond

# %% [markdown]
# ## CGC

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
import csv
import os

input_files = os.path.join('DNMT3A_inputs')

cgc=pd.read_csv(input_files+"/3A-CGC.int.hbonds", sep="\t", header=None)
cgc.columns = ["itype", "chain_a", "chain_b", "resname_a", "resname_b", "resid_a", "resid_b","atom_a", "atom_b" ]

cgc['resid_a'] = cgc['resid_a'] + 629

cgc_inter = cgc.loc[((cgc["chain_a"] == "A") & (cgc["chain_b"] == "B")) | 
                    ((cgc["chain_a"] == "A") & (cgc["chain_b"] == "C")) ]

cgc_spec = cgc_inter.drop(cgc_inter.index[cgc_inter['atom_b'].isin(["P","O1P","OP1","OP2","O2P","C5'",
                                                           "O5'","C4'","O4'","C3'","O3'","C2'",
                                                           "C1'","H1'","1H2'","2H2'","H3'","H4'","1H5'","2H5'"])])

cgc_spec_res = cgc_spec.drop(cgc_spec.index[cgc_spec['atom_a'].isin(["N","CA","C","O","H","HA"])])


cgc_spec_res["resname_a"] = cgc_spec_res["resname_a"].astype(str) + cgc_spec_res["resid_a"].astype(str)
#
cgc_spec_res=cgc_spec_res.drop(columns=['resid_a'])
cgc_spec_res['Type'] = '3A:CGC'
#
cgc_spec_res
# Out:
#         itype chain_a chain_b resname_a resname_b  resid_b atom_a atom_b  \
# 77      hbond       A       B    ARG720        DC      290    NH1     O2
# 79      hbond       A       B    ARG720        DC      290    NH2     O2
# 173     hbond       A       B    ARG836        DG      287     NE     O6
# 174     hbond       A       B    ARG836        DG      287    NH2     N7
# 259     hbond       A       C    GLU756        DC      298    OE1     N4
# ...       ...     ...     ...       ...       ...      ...    ...    ...
# 839123  hbond       A       C    ARG790        DC      298     NE     O2
# 839125  hbond       A       C    ARG790        DC      298    NH2     N3
# 839166  hbond       A       B    ARG836        DG      287     NE     O6
# 839167  hbond       A       B    ARG836        DG      287    NH2     N7
# 839245  hbond       A       C    GLU756        DC      298    OE1     N4
#
#           Type
# 77      3A:CGC
# 79      3A:CGC
# 173     3A:CGC
# 174     3A:CGC
# 259     3A:CGC
# ...        ...
# 839123  3A:CGC
# 839125  3A:CGC
# 839166  3A:CGC
# 839167  3A:CGC
# 839245  3A:CGC
#
# [17710 rows x 9 columns]

# %%
#Function for convert residue number of nucleotides to nucleotide position
def nucleotide_pos(df):
    df['resid_b'] = df['resid_b'].astype(str).str.replace('284',"(+5')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('285',"(+4')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('286',"(+3')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('287',"(+2')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('288',"(+1')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('289',"(0')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('290',"(-1')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('291',"(-2')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('292',"(-3')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('293',"(-4')")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('294',"(-4)")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('295',"(-3)")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('296',"(-2)")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('297',"(-1)")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('298',"(0)")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('299',"(+1)")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('300',"(+2)")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('301',"(+3)")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('302',"(+4)")
    df['resid_b'] = df['resid_b'].astype(str).str.replace('303',"(+5)")

# %%
nucleotide_pos(cgc_spec_res)
cgc_spec_res
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 77      hbond       A       B    ARG720        DC   (-1')    NH1     O2
# 79      hbond       A       B    ARG720        DC   (-1')    NH2     O2
# 173     hbond       A       B    ARG836        DG   (+2')     NE     O6
# 174     hbond       A       B    ARG836        DG   (+2')    NH2     N7
# 259     hbond       A       C    GLU756        DC     (0)    OE1     N4
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 839123  hbond       A       C    ARG790        DC     (0)     NE     O2
# 839125  hbond       A       C    ARG790        DC     (0)    NH2     N3
# 839166  hbond       A       B    ARG836        DG   (+2')     NE     O6
# 839167  hbond       A       B    ARG836        DG   (+2')    NH2     N7
# 839245  hbond       A       C    GLU756        DC     (0)    OE1     N4
#
#           Type
# 77      3A:CGC
# 79      3A:CGC
# 173     3A:CGC
# 174     3A:CGC
# 259     3A:CGC
# ...        ...
# 839123  3A:CGC
# 839125  3A:CGC
# 839166  3A:CGC
# 839167  3A:CGC
# 839245  3A:CGC
#
# [17710 rows x 9 columns]

# %%
cgc_spec_res['resname_a'] = cgc_spec_res['resname_a'].str.title()

#discarding flipped cytosine
cgc_spec_res=cgc_spec_res.drop(cgc_spec_res.loc[cgc_spec_res['resid_b']=="(0)"].index)
#
cgc_spec_res['pairwise'] = cgc_spec_res['resname_a'].str.cat(cgc_spec_res['resid_b'],sep="-")
cgc_spec_res['pair_freq'] = cgc_spec_res.groupby('pairwise')['pairwise'].transform('count')
#
cgc_spec_res['atom_atom'] = cgc_spec_res['resname_a']+"-"+ cgc_spec_res['atom_a']+"-"+ cgc_spec_res['resid_b'] +"-"+ cgc_spec_res['atom_b']
cgc_spec_res['atom_atom_freq'] = cgc_spec_res.groupby('atom_atom')['atom_atom'].transform('count')
#
cgc_spec_res
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 77      hbond       A       B    Arg720        DC   (-1')    NH1     O2
# 79      hbond       A       B    Arg720        DC   (-1')    NH2     O2
# 173     hbond       A       B    Arg836        DG   (+2')     NE     O6
# 174     hbond       A       B    Arg836        DG   (+2')    NH2     N7
# 348     hbond       A       B    Arg720        DC   (-1')    NH1     O2
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 838896  hbond       A       B    Arg836        DG   (+2')    NH2     N7
# 839066  hbond       A       B    Arg720        DA   (-2')    NH2     N9
# 839067  hbond       A       B    Arg720        DC   (-1')    NH2     O2
# 839166  hbond       A       B    Arg836        DG   (+2')     NE     O6
# 839167  hbond       A       B    Arg836        DG   (+2')    NH2     N7
#
#           Type      pairwise  pair_freq            atom_atom  atom_atom_freq
# 77      3A:CGC  Arg720-(-1')       5463  Arg720-NH1-(-1')-O2            2329
# 79      3A:CGC  Arg720-(-1')       5463  Arg720-NH2-(-1')-O2            3133
# 173     3A:CGC  Arg836-(+2')       6141   Arg836-NE-(+2')-O6            2479
# 174     3A:CGC  Arg836-(+2')       6141  Arg836-NH2-(+2')-N7            2382
# 348     3A:CGC  Arg720-(-1')       5463  Arg720-NH1-(-1')-O2            2329
# ...        ...           ...        ...                  ...             ...
# 838896  3A:CGC  Arg836-(+2')       6141  Arg836-NH2-(+2')-N7            2382
# 839066  3A:CGC  Arg720-(-2')        215  Arg720-NH2-(-2')-N9             192
# 839067  3A:CGC  Arg720-(-1')       5463  Arg720-NH2-(-1')-O2            3133
# 839166  3A:CGC  Arg836-(+2')       6141   Arg836-NE-(+2')-O6            2479
# 839167  3A:CGC  Arg836-(+2')       6141  Arg836-NH2-(+2')-N7            2382
#
# [12229 rows x 13 columns]

# %%
import warnings
warnings.filterwarnings('ignore')

cgc_compl = cgc_spec_res[cgc_spec_res['resid_b'].isin(("(+3')","(+2')","(+1')"))]
cgc_compl['Strand'] = 'CGC-compl'

cgc_target = cgc_spec_res[cgc_spec_res['resid_b'].isin(("(+3)","(+2)","(+1)"))]
cgc_target['Strand'] = 'CGC-target'

cgc_all=cgc_compl.append(cgc_target)
cgc_all=cgc_all.sort_values(('atom_atom_freq') , ascending=False)
cgc_all
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 173     hbond       A       B    Arg836        DG   (+2')     NE     O6
# 614092  hbond       A       B    Arg836        DG   (+2')     NE     O6
# 338495  hbond       A       B    Arg836        DG   (+2')     NE     O6
# 338762  hbond       A       B    Arg836        DG   (+2')     NE     O6
# 614862  hbond       A       B    Arg836        DG   (+2')     NE     O6
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 690516  hbond       A       C    Asn717        DG    (+1)    ND2     N3
# 673210  hbond       A       B    Ser837        DA   (+3')     OG     N6
# 673753  hbond       A       B    Ser837        DA   (+3')     OG     N6
# 705890  hbond       A       C    Asn717        DG    (+1)    ND2     N2
# 152418  hbond       A       C    Arg836        DG    (+1)    NH1     N7
#
#           Type      pairwise  pair_freq           atom_atom  atom_atom_freq  \
# 173     3A:CGC  Arg836-(+2')       6141  Arg836-NE-(+2')-O6            2479
# 614092  3A:CGC  Arg836-(+2')       6141  Arg836-NE-(+2')-O6            2479
# 338495  3A:CGC  Arg836-(+2')       6141  Arg836-NE-(+2')-O6            2479
# 338762  3A:CGC  Arg836-(+2')       6141  Arg836-NE-(+2')-O6            2479
# 614862  3A:CGC  Arg836-(+2')       6141  Arg836-NE-(+2')-O6            2479
# ...        ...           ...        ...                 ...             ...
# 690516  3A:CGC   Asn717-(+1)         19  Asn717-ND2-(+1)-N3               2
# 673210  3A:CGC  Ser837-(+3')         13  Ser837-OG-(+3')-N6               2
# 673753  3A:CGC  Ser837-(+3')         13  Ser837-OG-(+3')-N6               2
# 705890  3A:CGC   Asn717-(+1)         19  Asn717-ND2-(+1)-N2               1
# 152418  3A:CGC   Arg836-(+1)         27  Arg836-NH1-(+1)-N7               1
#
#             Strand
# 173      CGC-compl
# 614092   CGC-compl
# 338495   CGC-compl
# 338762   CGC-compl
# 614862   CGC-compl
# ...            ...
# 690516  CGC-target
# 673210   CGC-compl
# 673753   CGC-compl
# 705890  CGC-target
# 152418  CGC-target
#
# [6388 rows x 14 columns]

# %%
cgc_sig = cgc_all[cgc_all['atom_atom_freq'] > (3204*0.10)]

# %%
sns.set(style="ticks")
palet=['#cc7eb0', '#C71585']

plt.figure(figsize=(4,10))
ax = sns.barplot(x="atom_atom", y="atom_atom_freq", hue="Strand", palette=palet, 
                 data=cgc_sig,  lw=1, edgecolor='0.2')

plt.xticks(rotation=30)
plt.legend(loc='upper center')
plt.xticks(fontsize=22)
plt.yticks(fontsize=25)
plt.ylim(ymax = 2700, ymin = 0)
plt.xlabel('', fontsize=15, fontweight='bold')
plt.ylabel('Number of h-bonds',fontsize=28, fontweight='bold')
plt.title("",fontsize=20, fontweight='bold')

plt.savefig("Comp-3a-cgc-atom-atom-c-flank-a.pdf", dpi=600, bbox_inches='tight', format="pdf")

# %% [markdown]
# ## CGG

# %%
cgg=pd.read_csv(input_files+"/3A-CGG.int.hbonds", sep="\t", header=None)
cgg.columns = ["itype", "chain_a", "chain_b", "resname_a", "resname_b", "resid_a", "resid_b","atom_a", "atom_b" ]

cgg['resid_a'] = cgg['resid_a'] + 629

cgg_inter = cgg.loc[((cgg["chain_a"] == "A") & (cgg["chain_b"] == "B")) | 
                    ((cgg["chain_a"] == "A") & (cgg["chain_b"] == "C")) ]

cgg_spec = cgg_inter.drop(cgg_inter.index[cgg_inter['atom_b'].isin(["P","O1P","OP1","OP2","O2P","C5'",
                                                           "O5'","C4'","O4'","C3'","O3'","C2'",
                                                           "C1'","H1'","1H2'","2H2'","H3'","H4'","1H5'","2H5'"])])

cgg_spec_res = cgg_spec.drop(cgg_spec.index[cgg_spec['atom_a'].isin(["N","CA","C","O","H","HA"])])


cgg_spec_res["resname_a"] = cgg_spec_res["resname_a"].astype(str) + cgg_spec_res["resid_a"].astype(str)
#
cgg_spec_res=cgg_spec_res.drop(columns=['resid_a'])
cgg_spec_res['Type'] = '3A:CGG'
#
nucleotide_pos(cgg_spec_res)
cgg_spec_res
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 75      hbond       A       C    ASN717        DG    (+1)    ND2     N3
# 132     hbond       A       C    ARG790        DC     (0)    NH1     O2
# 171     hbond       A       C    ARG836        DT    (+3)    NH1     O4
# 172     hbond       A       B    ARG836        DG   (+4')    NH2     N7
# 173     hbond       A       C    ARG836        DT    (+3)    NH2     O4
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 836000  hbond       A       C    GLU756        DC     (0)    OE2     N4
# 836144  hbond       A       C    ARG792        DC     (0)    NH1     N3
# 836145  hbond       A       C    ARG792        DC     (0)    NH2     O2
# 836244  hbond       A       B    ASN838        DC   (+2')    OD1     N4
# 836251  hbond       A       C    GLU756        DC     (0)    OE2     N4
#
#           Type
# 75      3A:CGG
# 132     3A:CGG
# 171     3A:CGG
# 172     3A:CGG
# 173     3A:CGG
# ...        ...
# 836000  3A:CGG
# 836144  3A:CGG
# 836145  3A:CGG
# 836244  3A:CGG
# 836251  3A:CGG
#
# [20391 rows x 9 columns]

# %%
cgg_spec_res['resname_a'] = cgg_spec_res['resname_a'].str.title()

#discarding flipped cytosine
cgg_spec_res=cgg_spec_res.drop(cgg_spec_res.loc[cgg_spec_res['resid_b']=="(0)"].index)
#
cgg_spec_res['pairwise'] = cgg_spec_res['resname_a'].str.cat(cgg_spec_res['resid_b'],sep="-")
cgg_spec_res['pair_freq'] = cgg_spec_res.groupby('pairwise')['pairwise'].transform('count')
#
cgg_spec_res['atom_atom'] = cgg_spec_res['resname_a']+"-"+ cgg_spec_res['atom_a']+"-"+ cgg_spec_res['resid_b'] +"-"+ cgg_spec_res['atom_b']
cgg_spec_res['atom_atom_freq'] = cgg_spec_res.groupby('atom_atom')['atom_atom'].transform('count')
#
cgg_spec_res
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 75      hbond       A       C    Asn717        DG    (+1)    ND2     N3
# 171     hbond       A       C    Arg836        DT    (+3)    NH1     O4
# 172     hbond       A       B    Arg836        DG   (+4')    NH2     N7
# 173     hbond       A       C    Arg836        DT    (+3)    NH2     O4
# 346     hbond       A       C    Asn717        DG    (+1)    ND2     N3
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 835220  hbond       A       B    Asn838        DC   (+2')    OD1     N4
# 835478  hbond       A       B    Asn838        DC   (+2')    OD1     N4
# 835740  hbond       A       B    Asn838        DC   (+2')    OD1     N4
# 835990  hbond       A       B    Asn838        DC   (+2')    OD1     N4
# 836244  hbond       A       B    Asn838        DC   (+2')    OD1     N4
#
#           Type      pairwise  pair_freq            atom_atom  atom_atom_freq
# 75      3A:CGG   Asn717-(+1)         79   Asn717-ND2-(+1)-N3              46
# 171     3A:CGG   Arg836-(+3)        222   Arg836-NH1-(+3)-O4             143
# 172     3A:CGG  Arg836-(+4')        179  Arg836-NH2-(+4')-N7              37
# 173     3A:CGG   Arg836-(+3)        222   Arg836-NH2-(+3)-O4              69
# 346     3A:CGG   Asn717-(+1)         79   Asn717-ND2-(+1)-N3              46
# ...        ...           ...        ...                  ...             ...
# 835220  3A:CGG  Asn838-(+2')       1523  Asn838-OD1-(+2')-N4            1245
# 835478  3A:CGG  Asn838-(+2')       1523  Asn838-OD1-(+2')-N4            1245
# 835740  3A:CGG  Asn838-(+2')       1523  Asn838-OD1-(+2')-N4            1245
# 835990  3A:CGG  Asn838-(+2')       1523  Asn838-OD1-(+2')-N4            1245
# 836244  3A:CGG  Asn838-(+2')       1523  Asn838-OD1-(+2')-N4            1245
#
# [10653 rows x 13 columns]

# %%
cgg_compl = cgg_spec_res[cgg_spec_res['resid_b'].isin(("(+3')","(+2')","(+1')"))]
cgg_compl['Strand'] = 'cgg-compl'

cgg_target = cgg_spec_res[cgg_spec_res['resid_b'].isin(("(+3)","(+2)","(+1)"))]
cgg_target['Strand'] = 'cgg-target'

cgg_all=cgg_compl.append(cgg_target)
cgg_all=cgg_all.sort_values(('atom_atom_freq') , ascending=False)
cgg_all
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 509     hbond       A       B    Asn838        DC   (+2')    OD1     N4
# 573874  hbond       A       B    Asn838        DC   (+2')    OD1     N4
# 571794  hbond       A       B    Asn838        DC   (+2')    OD1     N4
# 215381  hbond       A       B    Asn838        DC   (+2')    OD1     N4
# 572062  hbond       A       B    Asn838        DC   (+2')    OD1     N4
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 753335  hbond       A       C    Lys844        DG    (+1)     NZ     N7
# 753334  hbond       A       C    Lys844        DG    (+1)     NZ     O6
# 423306  hbond       A       B    Arg836        DC   (+1')    NH2     N4
# 161661  hbond       A       C    Asn838        DG    (+2)    ND2     N7
# 102448  hbond       A       B    Asn838        DC   (+1')    OD1     N4
#
#           Type      pairwise  pair_freq            atom_atom  atom_atom_freq  \
# 509     3A:CGG  Asn838-(+2')       1523  Asn838-OD1-(+2')-N4            1245
# 573874  3A:CGG  Asn838-(+2')       1523  Asn838-OD1-(+2')-N4            1245
# 571794  3A:CGG  Asn838-(+2')       1523  Asn838-OD1-(+2')-N4            1245
# 215381  3A:CGG  Asn838-(+2')       1523  Asn838-OD1-(+2')-N4            1245
# 572062  3A:CGG  Asn838-(+2')       1523  Asn838-OD1-(+2')-N4            1245
# ...        ...           ...        ...                  ...             ...
# 753335  3A:CGG   Lys844-(+1)          2    Lys844-NZ-(+1)-N7               1
# 753334  3A:CGG   Lys844-(+1)          2    Lys844-NZ-(+1)-O6               1
# 423306  3A:CGG  Arg836-(+1')         11  Arg836-NH2-(+1')-N4               1
# 161661  3A:CGG   Asn838-(+2)         30   Asn838-ND2-(+2)-N7               1
# 102448  3A:CGG  Asn838-(+1')          9  Asn838-OD1-(+1')-N4               1
#
#             Strand
# 509      cgg-compl
# 573874   cgg-compl
# 571794   cgg-compl
# 215381   cgg-compl
# 572062   cgg-compl
# ...            ...
# 753335  cgg-target
# 753334  cgg-target
# 423306   cgg-compl
# 161661  cgg-target
# 102448   cgg-compl
#
# [6659 rows x 14 columns]

# %%
cgg_sig = cgg_all[cgg_all['atom_atom_freq'] > (3204*0.10)]

# %%
palet=['#DCDCDC', '#888888']

plt.figure(figsize=(6,10))
ax = sns.barplot(x="atom_atom", y="atom_atom_freq", hue="Strand", palette=palet, 
                 dodge=False,
                 data=cgg_sig,  lw=1, edgecolor='0.2')
plt.xticks(rotation=30)
plt.legend(loc='upper center')
plt.xticks(fontsize=22)
plt.yticks(fontsize=25)
plt.ylim(ymax = 2700, ymin = 0)
plt.xlabel('', fontsize=15, fontweight='bold')
plt.ylabel('',fontsize=15, fontweight='bold')
plt.title("",fontsize=20, fontweight='bold')

plt.savefig("Comp-3a-cgg-atom-atom-c-flank-a.pdf", dpi=600, bbox_inches='tight', format="pdf")

# %% [markdown]
# ## CGT

# %%
cgt=pd.read_csv(input_files+"/3A-CGT.int.hbonds", sep="\t", header=None)
cgt.columns = ["itype", "chain_a", "chain_b", "resname_a", "resname_b", "resid_a", "resid_b","atom_a", "atom_b" ]

cgt['resid_a'] = cgt['resid_a'] + 629

cgt_inter = cgt.loc[((cgt["chain_a"] == "A") & (cgt["chain_b"] == "B")) | 
                    ((cgt["chain_a"] == "A") & (cgt["chain_b"] == "C")) ]

cgt_spec = cgt_inter.drop(cgt_inter.index[cgt_inter['atom_b'].isin(["P","O1P","OP1","OP2","O2P","C5'",
                                                           "O5'","C4'","O4'","C3'","O3'","C2'",
                                                           "C1'","H1'","1H2'","2H2'","H3'","H4'","1H5'","2H5'"])])

cgt_spec_res = cgt_spec.drop(cgt_spec.index[cgt_spec['atom_a'].isin(["N","CA","C","O","H","HA"])])


cgt_spec_res["resname_a"] = cgt_spec_res["resname_a"].astype(str) + cgt_spec_res["resid_a"].astype(str)
#
cgt_spec_res=cgt_spec_res.drop(columns=['resid_a'])
cgt_spec_res['Type'] = '3A:CGT'
#
nucleotide_pos(cgt_spec_res)
cgt_spec_res
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 76      hbond       A       B    ARG720        DA   (-2')    NH2     N3
# 77      hbond       A       B    ARG720        DC   (-1')    NH2     O2
# 133     hbond       A       C    ARG790        DC     (0)    NH1     O2
# 134     hbond       A       C    ARG790        DC     (0)    NH2     N3
# 135     hbond       A       C    ARG790        DC     (0)    NH2     O2
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 837461  hbond       A       C    GLU756        DC     (0)    OE1     N4
# 837638  hbond       A       B    LYS844        DG    (0')     NZ     N7
# 837639  hbond       A       C    LYS844        DG    (-1)     NZ     O6
# 837803  hbond       A       B    ARG720        DC   (-1')    NH1     O2
# 837897  hbond       A       B    LYS844        DG    (0')     NZ     N7
#
#           Type
# 76      3A:CGT
# 77      3A:CGT
# 133     3A:CGT
# 134     3A:CGT
# 135     3A:CGT
# ...        ...
# 837461  3A:CGT
# 837638  3A:CGT
# 837639  3A:CGT
# 837803  3A:CGT
# 837897  3A:CGT
#
# [19554 rows x 9 columns]

# %%
cgt_spec_res['resname_a'] = cgt_spec_res['resname_a'].str.title()

#discarding flipped cytosine
cgt_spec_res=cgt_spec_res.drop(cgt_spec_res.loc[cgt_spec_res['resid_b']=="(0)"].index)
#
cgt_spec_res['pairwise'] = cgt_spec_res['resname_a'].str.cat(cgt_spec_res['resid_b'],sep="-")
cgt_spec_res['pair_freq'] = cgt_spec_res.groupby('pairwise')['pairwise'].transform('count')
#
cgt_spec_res['atom_atom'] = cgt_spec_res['resname_a']+"-"+ cgt_spec_res['atom_a']+"-"+ cgt_spec_res['resid_b'] +"-"+ cgt_spec_res['atom_b']
cgt_spec_res['atom_atom_freq'] = cgt_spec_res.groupby('atom_atom')['atom_atom'].transform('count')
#
cgt_spec_res
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 76      hbond       A       B    Arg720        DA   (-2')    NH2     N3
# 77      hbond       A       B    Arg720        DC   (-1')    NH2     O2
# 171     hbond       A       C    Arg836        DG    (+1)     NE     O6
# 173     hbond       A       C    Arg836        DG    (+1)    NH2     O6
# 342     hbond       A       B    Arg720        DC   (-1')    NH2     O2
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 837444  hbond       A       B    Ser837        DA   (+3')     OG     N6
# 837638  hbond       A       B    Lys844        DG    (0')     NZ     N7
# 837639  hbond       A       C    Lys844        DG    (-1)     NZ     O6
# 837803  hbond       A       B    Arg720        DC   (-1')    NH1     O2
# 837897  hbond       A       B    Lys844        DG    (0')     NZ     N7
#
#           Type      pairwise  pair_freq            atom_atom  atom_atom_freq
# 76      3A:CGT  Arg720-(-2')        777  Arg720-NH2-(-2')-N3             122
# 77      3A:CGT  Arg720-(-1')       4976  Arg720-NH2-(-1')-O2            3039
# 171     3A:CGT   Arg836-(+1)       2221    Arg836-NE-(+1)-O6             392
# 173     3A:CGT   Arg836-(+1)       2221   Arg836-NH2-(+1)-O6             427
# 342     3A:CGT  Arg720-(-1')       4976  Arg720-NH2-(-1')-O2            3039
# ...        ...           ...        ...                  ...             ...
# 837444  3A:CGT  Ser837-(+3')        381   Ser837-OG-(+3')-N6             227
# 837638  3A:CGT   Lys844-(0')        324    Lys844-NZ-(0')-N7              55
# 837639  3A:CGT   Lys844-(-1)        368    Lys844-NZ-(-1)-O6             334
# 837803  3A:CGT  Arg720-(-1')       4976  Arg720-NH1-(-1')-O2            1937
# 837897  3A:CGT   Lys844-(0')        324    Lys844-NZ-(0')-N7              55
#
# [10649 rows x 13 columns]

# %%
cgt_compl = cgt_spec_res[cgt_spec_res['resid_b'].isin(("(+3')","(+2')","(+1')"))]
cgt_compl['Strand'] = 'cgt-compl'

cgt_target = cgt_spec_res[cgt_spec_res['resid_b'].isin(("(+3)","(+2)","(+1)"))]
cgt_target['Strand'] = 'cgt-target'

cgt_all=cgt_compl.append(cgt_target)
cgt_all=cgt_all.sort_values(('atom_atom_freq') , ascending=False)
cgt_all
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 158680  hbond       A       C    Arg836        DG    (+1)    NH1     O6
# 96509   hbond       A       C    Arg836        DG    (+1)    NH1     O6
# 72224   hbond       A       C    Arg836        DG    (+1)    NH1     O6
# 72489   hbond       A       C    Arg836        DG    (+1)    NH1     O6
# 72752   hbond       A       C    Arg836        DG    (+1)    NH1     O6
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 85419   hbond       A       B    Lys844        DC   (+1')     NZ     N4
# 436505  hbond       A       B    Arg836        DC   (+1')     NE     N4
# 440598  hbond       A       B    Arg836        DC   (+1')     NE     N4
# 418252  hbond       A       B    Arg836        DA   (+2')    NH1     N7
# 778107  hbond       A       B    Asn838        DC   (+1')    ND2     N4
#
#           Type      pairwise  pair_freq            atom_atom  atom_atom_freq  \
# 158680  3A:CGT   Arg836-(+1)       2221   Arg836-NH1-(+1)-O6             544
# 96509   3A:CGT   Arg836-(+1)       2221   Arg836-NH1-(+1)-O6             544
# 72224   3A:CGT   Arg836-(+1)       2221   Arg836-NH1-(+1)-O6             544
# 72489   3A:CGT   Arg836-(+1)       2221   Arg836-NH1-(+1)-O6             544
# 72752   3A:CGT   Arg836-(+1)       2221   Arg836-NH1-(+1)-O6             544
# ...        ...           ...        ...                  ...             ...
# 85419   3A:CGT  Lys844-(+1')          3   Lys844-NZ-(+1')-N4               3
# 436505  3A:CGT  Arg836-(+1')         25   Arg836-NE-(+1')-N4               2
# 440598  3A:CGT  Arg836-(+1')         25   Arg836-NE-(+1')-N4               2
# 418252  3A:CGT  Arg836-(+2')         62  Arg836-NH1-(+2')-N7               1
# 778107  3A:CGT  Asn838-(+1')          1  Asn838-ND2-(+1')-N4               1
#
#             Strand
# 158680  cgt-target
# 96509   cgt-target
# 72224   cgt-target
# 72489   cgt-target
# 72752   cgt-target
# ...            ...
# 85419    cgt-compl
# 436505   cgt-compl
# 440598   cgt-compl
# 418252   cgt-compl
# 778107   cgt-compl
#
# [3719 rows x 14 columns]

# %%
cgt_sig = cgt_all[cgt_all['atom_atom_freq'] > (3204*0.10)]

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
import csv

palet=['orange', '#FFD491']
#palet=['orange']

plt.figure(figsize=(5,10))
ax = sns.barplot(x="atom_atom", y="atom_atom_freq", hue="Strand", palette=palet, 
                 dodge=False,
                 data=cgt_sig,  lw=1, edgecolor='0.2')
plt.xticks(rotation=30)
plt.legend(loc='upper center')
plt.xticks(fontsize=22)
plt.yticks(fontsize=25)
plt.ylim(ymax = 2700, ymin = 0)
plt.xlabel('', fontsize=15, fontweight='bold')
plt.ylabel('',fontsize=15, fontweight='bold')
plt.title("",fontsize=20, fontweight='bold')

plt.savefig("Comp-3a-cgt-atom-atom-c-flank-a.pdf", dpi=600, bbox_inches='tight', format="pdf")

# %% [markdown]
# ## CGA

# %%
cga=pd.read_csv(input_files+"/3A-CGA.int.hbonds", sep="\t", header=None)
cga.columns = ["itype", "chain_a", "chain_b", "resname_a", "resname_b", "resid_a", "resid_b","atom_a", "atom_b" ]

cga['resid_a'] = cga['resid_a'] + 629

cga_inter = cga.loc[((cga["chain_a"] == "A") & (cga["chain_b"] == "B")) | 
                    ((cga["chain_a"] == "A") & (cga["chain_b"] == "C")) ]

cga_spec = cga_inter.drop(cga_inter.index[cga_inter['atom_b'].isin(["P","O1P","OP1","OP2","O2P","C5'",
                                                           "O5'","C4'","O4'","C3'","O3'","C2'",
                                                           "C1'","H1'","1H2'","2H2'","H3'","H4'","1H5'","2H5'"])])

cga_spec_res = cga_spec.drop(cga_spec.index[cga_spec['atom_a'].isin(["N","CA","C","O","H","HA"])])


cga_spec_res["resname_a"] = cga_spec_res["resname_a"].astype(str) + cga_spec_res["resid_a"].astype(str)
#
cga_spec_res=cga_spec_res.drop(columns=['resid_a'])
cga_spec_res['Type'] = '3A:CGA'
#
nucleotide_pos(cga_spec_res)
cga_spec_res
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 81      hbond       A       B    ARG720        DC   (-1')    NH1     O2
# 83      hbond       A       B    ARG720        DC   (-1')    NH2     O2
# 136     hbond       A       C    ARG790        DC     (0)    NH2     O2
# 172     hbond       A       B    ARG836        DT   (+2')     NE     O4
# 173     hbond       A       C    ARG836        DG    (+1)    NH1     N7
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 834699  hbond       A       B    LYS844        DG    (0')     NZ     O6
# 834772  hbond       A       C    GLU756        DC     (0)    OE2     N4
# 834945  hbond       A       B    ARG836        DT   (+2')    NH1     O4
# 835020  hbond       A       C    GLU756        DC     (0)    OE1     N4
# 835021  hbond       A       C    GLU756        DC     (0)    OE2     N4
#
#           Type
# 81      3A:CGA
# 83      3A:CGA
# 136     3A:CGA
# 172     3A:CGA
# 173     3A:CGA
# ...        ...
# 834699  3A:CGA
# 834772  3A:CGA
# 834945  3A:CGA
# 835020  3A:CGA
# 835021  3A:CGA
#
# [16580 rows x 9 columns]

# %%
cga_spec_res['resname_a'] = cga_spec_res['resname_a'].str.title()

#discarding flipped cytosine
cga_spec_res=cga_spec_res.drop(cga_spec_res.loc[cga_spec_res['resid_b']=="(0)"].index)
#
cga_spec_res['pairwise'] = cga_spec_res['resname_a'].str.cat(cga_spec_res['resid_b'],sep="-")
cga_spec_res['pair_freq'] = cga_spec_res.groupby('pairwise')['pairwise'].transform('count')
#
cga_spec_res['atom_atom'] = cga_spec_res['resname_a']+"-"+ cga_spec_res['atom_a']+"-"+ cga_spec_res['resid_b'] +"-"+ cga_spec_res['atom_b']
cga_spec_res['atom_atom_freq'] = cga_spec_res.groupby('atom_atom')['atom_atom'].transform('count')
#
cga_spec_res
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 81      hbond       A       B    Arg720        DC   (-1')    NH1     O2
# 83      hbond       A       B    Arg720        DC   (-1')    NH2     O2
# 172     hbond       A       B    Arg836        DT   (+2')     NE     O4
# 173     hbond       A       C    Arg836        DG    (+1)    NH1     N7
# 348     hbond       A       B    Arg720        DC   (-1')    NH1     O2
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 834182  hbond       A       B    Arg836        DT   (+2')    NH1     O4
# 834433  hbond       A       B    Arg836        DT   (+2')    NH1     O4
# 834691  hbond       A       B    Arg836        DT   (+2')    NH1     O4
# 834699  hbond       A       B    Lys844        DG    (0')     NZ     O6
# 834945  hbond       A       B    Arg836        DT   (+2')    NH1     O4
#
#           Type      pairwise  pair_freq            atom_atom  atom_atom_freq
# 81      3A:CGA  Arg720-(-1')       3821  Arg720-NH1-(-1')-O2            1618
# 83      3A:CGA  Arg720-(-1')       3821  Arg720-NH2-(-1')-O2            2203
# 172     3A:CGA  Arg836-(+2')       2703   Arg836-NE-(+2')-O4              67
# 173     3A:CGA   Arg836-(+1)        569   Arg836-NH1-(+1)-N7             134
# 348     3A:CGA  Arg720-(-1')       3821  Arg720-NH1-(-1')-O2            1618
# ...        ...           ...        ...                  ...             ...
# 834182  3A:CGA  Arg836-(+2')       2703  Arg836-NH1-(+2')-O4            2622
# 834433  3A:CGA  Arg836-(+2')       2703  Arg836-NH1-(+2')-O4            2622
# 834691  3A:CGA  Arg836-(+2')       2703  Arg836-NH1-(+2')-O4            2622
# 834699  3A:CGA   Lys844-(0')        234    Lys844-NZ-(0')-O6             228
# 834945  3A:CGA  Arg836-(+2')       2703  Arg836-NH1-(+2')-O4            2622
#
# [8460 rows x 13 columns]

# %%
cga_compl = cga_spec_res[cga_spec_res['resid_b'].isin(("(+3')","(+2')","(+1')"))]
cga_compl['Strand'] = 'cga-compl'

cga_target = cga_spec_res[cga_spec_res['resid_b'].isin(("(+3)","(+2)","(+1)"))]
cga_target['Strand'] = 'cga-target'

cga_all=cga_compl.append(cga_target)
cga_all=cga_all.sort_values(('atom_atom_freq') , ascending=False)
cga_all
# Out:
#         itype chain_a chain_b resname_a resname_b resid_b atom_a atom_b  \
# 504392  hbond       A       B    Arg836        DT   (+2')    NH1     O4
# 559912  hbond       A       B    Arg836        DT   (+2')    NH1     O4
# 542574  hbond       A       B    Arg836        DT   (+2')    NH1     O4
# 542836  hbond       A       B    Arg836        DT   (+2')    NH1     O4
# 543087  hbond       A       B    Arg836        DT   (+2')    NH1     O4
# ...       ...     ...     ...       ...       ...     ...    ...    ...
# 12188   hbond       A       B    Asn838        DA   (+3')    ND2     N6
# 12960   hbond       A       B    Asn838        DA   (+3')    ND2     N6
# 28644   hbond       A       B    Asn838        DA   (+3')    ND2     N6
# 615269  hbond       A       C    Arg887        DT    (+3)     NE     O4
# 16063   hbond       A       C    Arg836        DA    (+2)    NH2     N7
#
#           Type      pairwise  pair_freq            atom_atom  atom_atom_freq  \
# 504392  3A:CGA  Arg836-(+2')       2703  Arg836-NH1-(+2')-O4            2622
# 559912  3A:CGA  Arg836-(+2')       2703  Arg836-NH1-(+2')-O4            2622
# 542574  3A:CGA  Arg836-(+2')       2703  Arg836-NH1-(+2')-O4            2622
# 542836  3A:CGA  Arg836-(+2')       2703  Arg836-NH1-(+2')-O4            2622
# 543087  3A:CGA  Arg836-(+2')       2703  Arg836-NH1-(+2')-O4            2622
# ...        ...           ...        ...                  ...             ...
# 12188   3A:CGA  Asn838-(+3')        102  Asn838-ND2-(+3')-N6               4
# 12960   3A:CGA  Asn838-(+3')        102  Asn838-ND2-(+3')-N6               4
# 28644   3A:CGA  Asn838-(+3')        102  Asn838-ND2-(+3')-N6               4
# 615269  3A:CGA   Arg887-(+3)          8    Arg887-NE-(+3)-O4               1
# 16063   3A:CGA   Arg836-(+2)         46   Arg836-NH2-(+2)-N7               1
#
#             Strand
# 504392   cga-compl
# 559912   cga-compl
# 542574   cga-compl
# 542836   cga-compl
# 543087   cga-compl
# ...            ...
# 12188    cga-compl
# 12960    cga-compl
# 28644    cga-compl
# 615269  cga-target
# 16063   cga-target
#
# [3532 rows x 14 columns]

# %%
cga_sig = cga_all[cga_all['atom_atom_freq'] > (3204*0.10)]

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
import csv

#palet=['#C71585','#DCDCDC', 'orange', 'lightseagreen']
palet=['#87D3D3','lightseagreen']

plt.figure(figsize=(1,10))
ax = sns.barplot(x="atom_atom", y="atom_atom_freq", hue="Strand", palette=palet, 
                 dodge=False,
                 data=cga_sig,  lw=1, edgecolor='0.2')
plt.xticks(rotation=30)
plt.legend('')
plt.xticks(fontsize=22)
plt.yticks(fontsize=25)
plt.ylim(ymax = 2700, ymin = 0)
plt.xlabel('', fontsize=15, fontweight='bold')
plt.ylabel('',fontsize=15, fontweight='bold')
plt.title("",fontsize=20, fontweight='bold')

plt.savefig("Comp-3a-cga-atom-atom-c-flank-a.pdf", dpi=600, bbox_inches='tight', format="pdf")
